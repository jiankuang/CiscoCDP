# %%
import dao
import matplotlib.pyplot as plt
# Out:
# Requesting **Real Time Data** (http://10.10.20.6/apigw/devnetlabapi/cdp/v1/devices/parking?UserKey=500103&SensorCustomerKey=500050&AppKey=CDP-App)

# %%
labels = ['Empty', 'Occupied']
values = [0,0]
spots = dao.getAllParkingSpots()

for r in spots:
    if 'ParkingSpot' in r:
        spot = r['ParkingSpot']
        # we now have an instance of a Smart+Connected Digital Platform light model
        # get the 'state' object
        # this contains 'intensityLevel', 'powerConsumption' and 'reliability'
        if spot['state']:
            state = spot['state']
        # increment the values array
        if state['occupied'] == False:
            values[0] = values[0] + 1
        else:
            values[1] = values[1] + 1
            
plt.pie(values, labels=labels, autopct='%1.1f%%', shadow=True)
# make the graph a circle (not setting this can result an an elipsis)
plt.axis('equal')
# set the title of the plot and add some additional information - the total number of lights
plt.title('Current Parking States (Total Spots '+ str(values[0] + values[1]) + ')')
# show the graph
plt.show()

# %%
# scatter plot 70 spots in 4 parking spaces according to coordicates
def jsonListToDF(jsonList, dataType):
    data = [json[dataType] for json in jsonList]
    df_data = pd.read_json(json.dumps(data)) 
    return df_data

df_spots = jsonListToDF(spots, 'ParkingSpot') # [spot['ParkingSpot'] for spot in spots]
df_spots['longitude'] = [geo['longitude'] for geo in df_spots['geocoordinates']]
df_spots['latitude'] = [geo['latitude'] for geo in df_spots['geocoordinates']]
df_space1 = df_spots[df_spots['parkingSpaceId'] == 'Simulated__DEVNET002__spacez001']
df_space2 = df_spots[df_spots['parkingSpaceId'] == 'Simulated__DEVNET002__spacez002']
df_spaceB1 = df_spots[df_spots['parkingSpaceId'] == 'Simulated__DEVNET002__spacezBell001']

fig, axes = plt.subplots(2, 2, figsize=(12,10))
axes[0,0].scatter(df_space1['longitude'], df_space1['latitude'], label='spacez001', color='c')
axes[0,0].scatter(df_space2['longitude'], df_space2['latitude'], label='spacez002', color='y')
axes[0,0].scatter(df_spaceB1['longitude'], df_spaceB1['latitude'], label='spacezBell001', color='g')
axes[0,0].legend()
axes[0,1].scatter(df_space1['longitude'], df_space1['latitude'], color='c')
axes[0,1].set_xlim([-121.9325,-121.924])
axes[0,1].set_ylim([37.405,37.411])
axes[1,0].scatter(df_space2['longitude'], df_space2['latitude'], color='y')
axes[1,0].set_xlim([77.023,77.03])
axes[1,0].set_ylim([28.456,28.463])
axes[1,1].scatter(df_spaceB1['longitude'], df_spaceB1['latitude'], color='g')
axes[1,1].set_xlim([-113.628,-113.618])
axes[1,1].set_ylim([53.521,53.527])
plt.show()

# %%
# do some analylsis on Sparking Spaces
import json
import numpy as np
import pandas as pd
spaces = dao.getAllParkingSpaces()

print("We totally have %s Parking Spaces" % len(spaces))

data = [space['ParkingSpace'] for space in spaces]
df_data = pd.read_json(json.dumps(data)) 
df_data['total'] = [state['total'] for state in df_data['state']]
df_data
# Out:
# Requesting **Real Time Data** (http://10.10.20.6/apigw/devnetlabapi/cdp/v1/devices/parking?UserKey=500103&SensorCustomerKey=500050&AppKey=CDP-App)
#
# We totally have 4 Parking Spaces
#                                             boundary demarcated  \
# 0  {'geoPoint': [{'longitude': None, 'latitude': ...       True
# 1  {'geoPoint': [{'longitude': -121.9250196, 'lat...       True
# 2  {'geoPoint': [{'longitude': 77.02938509, 'lati...       True
# 3  {'geoPoint': [{'longitude': -113.6195862, 'lat...       True
#
#                   hierId                label  \
# 0  parking_hierarchy_sid  Space Bell Zone 001
# 1  parking_hierarchy_sid       Space Zone 001
# 2  parking_hierarchy_sid       Space Zone 002
# 3  parking_hierarchy_sid     SpaceBellZone001
#
#                                             opParams  \
# 0                       {'zoneType': 'ValidParking'}
# 1  {'parkingRate': {'durationMinutes': 60, 'fareP...
# 2                       {'zoneType': 'ValidParking'}
# 3                       {'zoneType': 'ValidParking'}
#
#                                      providerDetails    sensorCustomerId  \
# 0  {'providerId': 'kvt7gvsfwkqoa2wikma5btvdz3lnqk...  SDPCustomer_500050
# 1  {'providerId': 'kvt7gvsfwkqoa2wikma5btvdz3lnqk...  SDPCustomer_500050
# 2  {'providerId': 'kvt7gvsfwkqoa2wikma5btvdz3lnqk...  SDPCustomer_500050
# 3  {'providerId': 'kvt7gvsfwkqoa2wikma5btvdz3lnqk...  SDPCustomer_500050
#
#                                      sid  \
# 0  Simulated__DEVNET002__spacez Bell 001
# 1        Simulated__DEVNET002__spacez001
# 2        Simulated__DEVNET002__spacez002
# 3    Simulated__DEVNET002__spacezBell001
#
#                                          state     thirdPartyId  total
# 0   {'total': 0, 'floating': 0, 'occupied': 0}  spacez Bell 001      0
# 1  {'total': 20, 'floating': 0, 'occupied': 0}        spacez001     20
# 2  {'total': 20, 'floating': 0, 'occupied': 0}        spacez002     20
# 3  {'total': 30, 'floating': 0, 'occupied': 0}    spacezBell001     30

# %%
y_pos = np.arange(len(df_data['total']))
plt.bar(y_pos, df_data['total'])
plt.xticks(y_pos, df_data['label'])
plt.xticks(rotation=10)
plt.ylabel('Number of Parking Spots')
plt.title("Number of Parking Spots in Each Parking Space")
plt.show()

# %%
sensors = dao.getAllEnvironmentSensors()

print("We totally have %s Environment Sensors" % len(sensors))

data = [sensor['EnvironmentSensor'] for sensor in sensors]
df_data = pd.read_json(json.dumps(data)) 
df_data['sensorType'] = [type[0] for type in df_data['sensorType']]
df_data.head()
# Out:
# Requesting **Real Time Data** (http://10.10.20.6/apigw/devnetlabapi/cdp/v1/devices/environment?UserKey=500103&SensorCustomerKey=500050&AppKey=CDP-App)
#
# We totally have 259 Environment Sensors
#                                           airQuality ambientLight  \
# 0  {'reading': {'co2': {'value': 8.0}, 'no2': {'v...          NaN
# 1  {'reading': {'co2': {'value': 2.0}, 'no2': {'v...          NaN
# 2  {'reading': {'co2': {'value': 5.0}, 'no2': {'v...          NaN
# 3  {'reading': {'co2': {'value': 1.0}, 'no2': {'v...          NaN
# 4  {'reading': {'co2': {'value': 1.0}, 'no2': {'v...          NaN
#
#   ambientNoise ambientTemperature deviceType  \
# 0          NaN                NaN     Sensor
# 1          NaN                NaN     Sensor
# 2          NaN                NaN     Sensor
# 3          NaN                NaN     Sensor
# 4          NaN                NaN     Sensor
#
#                                       geocoordinates label  \
# 0  {'latitude': 37.40235174, 'longitude': -121.94...   AQ1
# 1  {'latitude': 37.41814266, 'longitude': -121.93...  AQ10
# 2  {'latitude': 37.39807744, 'longitude': -121.94...  AQ11
# 3  {'latitude': 37.40259387, 'longitude': -121.92...  AQ12
# 4  {'latitude': 37.40372584, 'longitude': -121.92...  AQ13
#
#                 lastUpdated  \
# 0  2017-01-10T13:11:34.878Z
# 1  2017-01-10T13:11:34.878Z
# 2  2017-01-10T13:11:34.878Z
# 3  2017-01-10T13:11:34.878Z
# 4  2017-01-10T13:11:34.878Z
#
#                                      providerDetails    sensorCustomerId  \
# 0  {'provider': 'simulator', 'providerId': 'udvdd...  SDPCustomer_500050
# 1  {'provider': 'simulator', 'providerId': 'udvdd...  SDPCustomer_500050
# 2  {'provider': 'simulator', 'providerId': 'udvdd...  SDPCustomer_500050
# 3  {'provider': 'simulator', 'providerId': 'udvdd...  SDPCustomer_500050
# 4  {'provider': 'simulator', 'providerId': 'udvdd...  SDPCustomer_500050
#
#    sensorType                         sid thirdPartyId
# 0  AirQuality   Simulated__DEVNET002__AQ1          AQ1
# 1  AirQuality  Simulated__DEVNET002__AQ10         AQ10
# 2  AirQuality  Simulated__DEVNET002__AQ11         AQ11
# 3  AirQuality  Simulated__DEVNET002__AQ12         AQ12
# 4  AirQuality  Simulated__DEVNET002__AQ13         AQ13

# %%
# plt.hist(df_data['sensorType'].values)
unique, counts = np.unique(df_data['sensorType'].values, return_counts=True)
rects = plt.bar(range(len(unique)), counts)
plt.xticks(range(len(unique)), unique)
plt.xticks(rotation=10)
plt.ylabel('Number of Sensors')
plt.title("Number for Each Sensor Types")
axes = plt.gca()
axes.set_ylim([0,80])
def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')

autolabel(rects)
plt.show()
